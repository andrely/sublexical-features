# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), 'BrownClustering'))
sys.path.append(os.path.join(os.getcwd(), 'Corpora'))
# %load_ext autoreload
# %autoreload 2

# %%
from glob import glob

import nltk
from sklearn.feature_extraction.text import CountVectorizer

from corpora.newsgroups import corpus_path, parse_articles

# %%
vect = CountVectorizer(max_features=500, decode_error='ignore')
vect.fit((article['body'] for article in parse_articles(corpus_path)))
# Out:
# CountVectorizer(analyzer=u'word', binary=False, charset=None,
#         charset_error=None, decode_error='ignore',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=500, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vect.vocabulary_
# Out:
# {u'10': 0,
#  u'100': 1,
#  u'11': 2,
#  u'12': 3,
#  u'14': 4,
#  u'15': 5,
#  u'16': 6,
#  u'1993': 7,
#  u'20': 8,
#  u'24': 9,
#  u'25': 10,
#  u'30': 11,
#  u'50': 12,
#  u'93': 13,
#  u'able': 14,
#  u'about': 15,
#  u'above': 16,
#  u'ac': 17,
#  u'access': 18,
#  u'actually': 19,
#  u'address': 20,
#  u'advance': 21,
#  u'after': 22,
#  u'again': 23,
#  u'against': 24,
#  u'ago': 25,
#  u'agree': 26,
#  u'all': 27,
#  u'almost': 28,
#  u'already': 29,
#  u'also': 30,
#  u'although': 31,
#  u'always': 32,
#  u'am': 33,
#  u'american': 34,
#  u'an': 35,
#  u'and': 36,
#  u'another': 37,
#  u'answer': 38,
#  u'any': 39,
#  u'anybody': 40,
#  u'anyone': 41,
#  u'anything': 42,
#  u'anyway': 43,
#  u'are': 44,
#  u'area': 45,
#  u'around': 46,
#  u'article': 47,
#  u'as': 48,
#  u'ask': 49,
#  u'at': 50,
#  u'available': 51,
#  u'away': 52,
#  u'back': 53,
#  u'bad': 54,
#  u'based': 55,
#  u'be': 56,
#  u'because': 57,
#  u'become': 58,
#  u'been': 59,
#  u'before': 60,
# ...
