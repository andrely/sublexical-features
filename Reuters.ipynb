# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), 'BrownClustering'))
sys.path.append(os.path.join(os.getcwd(), 'Corpora'))
sys.path.append(os.path.join(os.getcwd(), 'Experiments'))
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import BeautifulSoup as bs4
from glob import glob

from sklearn.feature_extraction.text import CountVectorizer

from corpora import reuters
from experiments.reuters import corpus_statistics

# %%
corpus_fns = glob(os.path.join(reuters.corpus_path, '*.sgm'))

# %%
topics = set()
places = set()
people = set()
orgs = set()
exchanges = set()
companies = set()

for article in reuters.corpus_articles(reuters.corpus_path):
    topics |= set(article['topics'])
    places |= set(article['places'])
    people |= set(article['people'])
    orgs |= set(article['orgs'])
    # exchanges |= set(article['exchanges'])
    # companies |= set(article['companies'])
# Out:
# WARNING:root:Missing body for id 30 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 31 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 76 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 77 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 78 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 92 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 94 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 95 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 99 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 101 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# ...

# %%
count, topic_counts = corpus_statistics(reuters.corpus_path)
# Out:
# WARNING:root:Missing body for id 30 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 31 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 76 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 77 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 78 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 92 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 94 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 95 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 99 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 101 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# ...

# %%
topic_counts
# Out:
# Counter({u'earn': 3776, u'acq': 2210, u'money-fx': 684, u'grain': 574, u'crude': 566, u'trade': 515, u'interest': 424, u'ship': 295, u'wheat': 287, u'corn': 224, u'oilseed': 182, u'sugar': 175, u'dlr': 168, u'gnp': 153, u'coffee': 143, u'veg-oil': 136, u'gold': 133, u'nat-gas': 126, u'money-supply': 126, u'livestock': 112, u'soybean': 111, u'bop': 101, u'cpi': 101, u'copper': 77, u'carcass': 75, u'reserves': 73, u'jobs': 68, u'cocoa': 68, u'rice': 67, u'iron-steel': 65, u'cotton': 62, u'yen': 58, u'alum': 58, u'ipi': 57, u'gas': 55, u'meal-feed': 50, u'rubber': 49, u'barley': 48, u'zinc': 43, u'palm-oil': 42, u'pet-chem': 41, u'silver': 36, u'lead': 35, u'rapeseed': 35, u'sorghum': 34, u'tin': 33, u'strategic-metal': 32, u'wpi': 29, u'fuel': 28, u'hog': 26, u'soy-meal': 26, u'orange': 25, u'soy-oil': 25, u'heat': 25, u'retail': 23, u'housing': 18, u'sunseed': 17, u'stg': 17, u'lumber': 17, u'tea': 15, u'dmk': 14, u'lei': 13, u'oat': 13, u'income': 12, u'platinum': 11, u'nickel': 11, 
# ...

# %%
vect = CountVectorizer([article['body'] for article in reuters.corpus_articles(reuters.corpus_path)],
                       max_features=500)
# Out:
#   File "<ipython-input-120-23b4e3f70633>", line 1
#     vect = CountVectorizer([article['body'] for article in reuters.corpus_articles(reuters.corpus_path)],
#                                            ^
# SyntaxError: invalid syntax

# %%
[article['body'] for article in reuters.corpus_articles(reuters.corpus_path)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-e1f1845d6efe> in <module>()
# ----> 1 [article['body'] for article in reuters.corpus_articles(reuters.corpus_path)[0:3]]
#
# TypeError: 'generator' object has no attribute '__getitem__'

# %%
it = reuters.corpus_articles(reuters.corpus_path)

# %%
vect = CountVectorizer(max_features=500)
vect.fit((article['body'] for article in reuters.corpus_articles(reuters.corpus_path)))
# Out:
# WARNING:root:Missing body for id 30 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 31 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 76 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 77 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 78 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 92 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 94 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 95 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 99 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# WARNING:root:Missing body for id 101 in /Users/stinky/Work/data/reuters21578/reut2-000.sgm
# ...

# %%
vect.vocabulary_
# Out:
# {u'000': 0,
#  u'10': 1,
#  u'100': 2,
#  u'11': 3,
#  u'12': 4,
#  u'13': 5,
#  u'14': 6,
#  u'15': 7,
#  u'16': 8,
#  u'17': 9,
#  u'18': 10,
#  u'19': 11,
#  u'1985': 12,
#  u'1986': 13,
#  u'1987': 14,
#  u'1988': 15,
#  u'20': 16,
#  u'200': 17,
#  u'21': 18,
#  u'22': 19,
#  u'23': 20,
#  u'24': 21,
#  u'25': 22,
#  u'26': 23,
#  u'27': 24,
#  u'28': 25,
#  u'29': 26,
#  u'30': 27,
#  u'300': 28,
#  u'31': 29,
#  u'32': 30,
#  u'35': 31,
#  u'40': 32,
#  u'45': 33,
#  u'50': 34,
#  u'500': 35,
#  u'60': 36,
#  u'70': 37,
#  u'75': 38,
#  u'80': 39,
#  u'90': 40,
#  u'about': 41,
#  u'according': 42,
#  u'acquire': 43,
#  u'acquired': 44,
#  u'acquisition': 45,
#  u'action': 46,
#  u'added': 47,
#  u'additional': 48,
#  u'administration': 49,
#  u'after': 50,
#  u'against': 51,
#  u'agency': 52,
#  u'ago': 53,
#  u'agreed': 54,
#  u'agreement': 55,
#  u'agriculture': 56,
#  u'all': 57,
#  u'already': 58,
#  u'also': 59,
#  u'although': 60,
#  u'american': 61,
#  u'amount': 62,
# ...
